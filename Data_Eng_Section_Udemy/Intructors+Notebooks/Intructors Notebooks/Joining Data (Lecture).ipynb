# %% [markdown]
# ## Joining Data
# ### Links and Resources
# - https://spark.apache.org/docs/3.1.3/api/python/reference/api/pyspark.sql.DataFrame.join.html

# %%
path_orders = "Files/retail_dataset_de/orders"
df_orders = spark.read.format("parquet").load(path_orders)
display(df_orders.limit(5))

path_products = "Files/retail_dataset_de/products.parquet"
df_products = spark.read.format("parquet").load(path_products)
display(df_products.limit(5))
# Out:
# StatementMeta(, 95c4632a-09a9-45b6-a2e3-9617861a2f51, 12, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 6d027ffd-07ef-4278-908d-bf46935aabd7)
# SynapseWidget(Synapse.DataFrame, fa4ca923-d5f5-43f0-803b-ea13af940731)

# %%
# joining df_orders and df_products
df_join = display(df_orders.join(df_products, df_orders["product_id"]==df_products["id"], 'left'))

display(df_join)
# Out:
# StatementMeta(, 95c4632a-09a9-45b6-a2e3-9617861a2f51, 13, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 1b3aee0f-cdc9-4063-953d-a6c751420b24)

# %%
df_join = df_orders.\
                join(df_products, df_orders["product_id"]==df_products["id"], 'left').\
                select(
                            df_orders['id'],
                            df_orders['created_at'],
                            df_orders['user_id'],
                            df_orders['quantity'],
                            df_orders['unit_price'], 
                            df_products['title'], 
                            df_products['category'],
                            df_products['vendor']
                        )
                
display(df_join)
# Out:
# StatementMeta(, 95c4632a-09a9-45b6-a2e3-9617861a2f51, 24, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 4aeb01fa-daea-4d0a-aeff-293318d694b5)
